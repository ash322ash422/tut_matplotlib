# %% [markdown]
# # Concepts covered
# - scatter, plot, line, marker, subplot
# - label x-axis, y-axis
# - adding title. legend
# - save figure into a file
# - read a CSV file

# %%
# !pip install matplotlib

# %%
# import libraries
import matplotlib.pyplot as plt # create alias plt
import numpy as np

# %% [markdown]
# # scatter plot

# %%
xpoints = [20, 25, 50] # age
ypoints = [40, 55, 60] # wt

plt.scatter(xpoints, ypoints ) 
# plt.scatter(xpoints, ypoints, marker='+') # marker as o, *, +
# plt.scatter(xpoints, ypoints, marker='+', color='orange') 

plt.show()

#########
# Or I can also use numpy array to display data

# import numpy as np

# xpoints = np.array([20, 25, 50]) # age
# ypoints = np.array([40, 55, 60]) # wt

# plt.scatter(xpoints, ypoints, ) # marker as o, *, +
# plt.show()

# %%
## SKIP
import matplotlib.pyplot as plt
import numpy as np

# simple scatter plot
x = np.array([5, 7, 8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
# Now I want to plot graph of 2 different pairs

# Simulated real-world data: Study hours vs Test scores

# Alice's study hours and scores (less consistent results)
x_alice = [2,  3,   4,  5,  6,  7,  8]
y_alice = [50, 55, 58, 60, 65, 67, 68]

# Bob's study hours and scores (more consistent and higher performing)
x_bob = [2,   3,  4,  5,  6,  7,  8]
y_bob = [55, 60, 65, 70, 75, 78, 82]

plt.figure(figsize=(10, 3)) # size = (length, width)

# Plotting data
plt.scatter(x_alice, y_alice, color='green',   marker='o', label='Alice')
plt.scatter(x_bob,   y_bob,   color='magenta', marker='s', label='Bob')


plt.xlabel("Hours Studied")
plt.ylabel("Test Scores")
plt.title("Relationship Between Study Time and Test Performance")
plt.legend()
plt.grid(True)
plt.ylim(0, 100)
plt.xlim(1, 9)

plt.show()

# %%
# Now I want to display 3 features in 2D graph

# Now I want to plot each  point and color each point based on score

x = [5,7,8,7,2,17,2,9,4,11,12,9,6] # hours studied
y = [99,86,87,88,111,86,103,87,94,78,77,85,86] # scores
colors = y  # color each point

plt.scatter(x, y, c=colors, cmap='gist_earth') #TODO other cmap are Oranges viridis gist_earth
plt.colorbar() # to display side colorbar

plt.show()

# %%
# Now I want to display 4 features in 2D graph
# Create random arrays with 100 values for x-points, y-points, colors and sizes:
import matplotlib.pyplot as plt 
import numpy as np

size = 10
x = np.random.randint(20, 101, size=size)  # Age range: 20 to 100
y = np.random.randint(20000, 70001, size=size)  # Income range: 20,000 to 70,000
dept = np.random.randint(100, size=size) # department
titles = np.random.choice([20, 50, 100, 150], size=size) # title: Manager, S/w developer, Dr.
# print(f"titles: {titles}") # TODO

# # Generate 10 random points
# x = np.array([20, 30, 40, 60, 80]) # age salary
# y = np.array([20000, 45000, 60000, 30000, 50000]) # salary
# dept = np.array([100, 50, 20, 100, 50]) #  d0epartment
# titles =  np.array([500, 60, 200, 60, 200]) # title

plt.scatter(x, y, c=titles, s=dept, alpha=0.9, cmap='nipy_spectral') #NOTE change alpha from 0, 0.2, 0.5, 0.8, 1.

plt.colorbar()

plt.show()

# %%
# I want to plot using scatterplot:  y = 5(x^2) -3x + 1

x = np.linspace(-4, 4, 30) # generate 30 points between -4 to +4
y = 5*(x**2) - 3*x + 1 

plt.scatter(x, y, marker=".") # "g-"

plt.show()

# %%
# annotate each points
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, y, color='blue')

# Annotate points with text
ax.text(x[0], y[0], "Point 1", ha="center", va="center", color="black")
ax.text(x[1], y[1], "Point 2", ha="center", va="center", color="black")
ax.text(x[2], y[2], "Point 3", ha="center", va="center", color="black")

# or use for loop
# for i in range(len(x)):
#     ax.text(x[i], y[i], f"Point {i+1}", ha="center", va="center", color="black")

# Set labels and title
ax.set_title('Scatter Plot with Annotations')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# # read from a CSV file

# %%
# read from CSV file
import matplotlib.pyplot as plt # create alias plt
import pandas as pd

df = pd.read_csv("some_data.csv")

#Use below to read raw file directly from github. This is the URL obtained when we click raw button.
# df = pd.read_csv("https://raw.githubusercontent.com/ash322ash422/tut_matplotlib/bdbc0716c93775dd1995c841a290eebb67fecb61/some_data.csv")

print(f"df:\n{df}")
print("#######################")
x = df['Sales']
y = df['Profits']

plt.scatter(x, y) # marker as o, *, +

plt.xticks(rotation=45)
plt.xlabel("Sales")
plt.ylabel("Profits")

plt.show()

# %%
x = df['Date']
y = df['Profits']

plt.plot(x,y, marker='*')
plt.xticks(rotation=45)
plt.xlabel("Sales")
plt.ylabel("Expenses")

plt.show()

# %% [markdown]
# # Line plot

# %%
# line plots

# step1: plot (20,40), (25,55), (50,60)
x = [20, 25, 50] # age
y = [40, 55, 60] # wt

plt.plot(x,y)
plt.show() # render

# %%
# step: Lets add Markers

# plot (20,40), (25,55), (50,60)
x = [20, 25, 50] # age
y = [40, 55, 60] # wt


plt.plot(x, y, marker = 'X') # NOTE try markers * . + o D etc
plt.show() # render

# %%
# step3: different styles of line plot
x = [20, 25, 50] # age
y = [40, 55, 60] # wt

# You can also use the shortcut string notation parameter to specify the marker.
# This parameter is also called fmt, and is written with this syntax: marker|line|color
plt.plot(x,y, 'D-.g') # NOTE other examples: o--b o--r o:g o:r o-r o-.r 'o--g'
plt.show() # render

# %%
# step4: marker size is 20
import matplotlib.pyplot as plt

x = [20, 25, 50] # age
y = [40, 55, 60] # wt

plt.plot(x,y, marker = 'o', ms = 20) # ms is marker size
plt.show() # render

# %%
# step5: Plot with a 20.5pt wide line:

x = [20, 25, 50] # age
y = [40, 55, 60] # wt

plt.plot(x, y, marker = 'o', ms = 20, linewidth = '10.5') 
plt.show() # render

# %%
# (SKIP) Lets plot different syle of markers
import numpy as np
import matplotlib.pyplot as plt

markers = [

'.', # point
',', # pixel
'o', # circle
'v', # triangle down
'^', # triangle up
'<', # triangle_left
'>', # triangle_right
'1', # tri_down
'2', # tri_up
'3', # tri_left
'4', # tri_right
'8', # octagon
's', # square
'p', # pentagon
'*', # star
'h', # hexagon1
'H', # hexagon2
'+', # plus
'x', # x
'D', # diamond
'd', # thin_diamond
'|', # vline

]

plt.figure(figsize=(13, 10))
samples = range(len(markers))


for i in samples:
    plt.plot([i-1, i, i+1], [i, i, i], label=markers[i], marker=markers[i], markersize=10)


# Annotation

plt.title('Matplotlib Marker styles', fontsize=20)
plt.ylim([-1, len(markers)+1])
plt.legend(loc='lower right')


plt.show()

# %%
# I want to line plot 3 pairs of variables

# Bob
x1 = [20, 25, 50] # age
y1 = [40, 55, 60] # wt

# Tanner
x2 = [20, 25, 50] # age
y2 = [80, 100, 30] # wt

# Prasad
x3 = [20, 25, 50] # age
y3 = [45, 10, 90] # wt


plt.plot(x1, y1, linewidth='1')
plt.plot(x2, y2, linewidth='2')
plt.plot(x3, y3, linewidth='4')

plt.show() # render

# %%
# I want 2 plot functions on same graph: y = x^2, y = -x^2

x = np.linspace(-1.5, 1.5, 30) # generate 30 points between -1.5 to +1.5
y1 = x**2
y2 = -x**2


plt.plot(x, y1, "b-")
plt.plot(x, y2, "g-")

plt.show()

# %%
# SKIP : Lets look at some line styles

linestyles = ['-.', '--', 'None', '-', ':']

plt.figure(figsize=(8, 5))
samples = range(len(linestyles))


for i in samples:
    plt.plot([i-1, i, i+1], [i, i, i],
             label='"%s"' %linestyles[i],
             linestyle=linestyles[i],
             lw=4
             )

# Annotation

plt.title('Matplotlib line styles', fontsize=20)
plt.ylim([-1, len(linestyles)+1])
plt.legend(loc='lower right')


plt.show()

# %%
# (SKIP)Labels
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Body Data", fontdict = font1)
plt.xlabel("Height", fontdict = font2)
plt.ylabel("weight", fontdict = font2)

plt.show()

# %% [markdown]
# ## Plot a curve and save the figure

# %%
# Plot a curve and save the figure

x = np.linspace(-4, 4, 30) # generate 30 points between -4 to +4
y = 5*(x**2) - 3*x + 1 # y = 5(x^2) -3x + 1
# y = -1.5*(x**3) + 10 # y = -1.5(x^3) + 10

# print(f"x : {x}") 
# print(f"y : {y}")

plt.plot(x, y, marker="D")

plt.savefig("quad.png") # replaced plt.show()

# %%
# Lets add some text 

from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-1.5, 1.5, 30) # generate 30 points between -1.5 to +1.5
y = x**2

x_point = 0.8 # an x-point
y_point = x_point**2 # corresponding y point

#following plots a curve and a point
plt.plot(x, y, "g-", # plots a curve
         x_point, y_point, "ro" # plots a point
)

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='red', horizontalalignment="center")
plt.text(x_point - 0.08, y_point, "Beautiful point", ha="right", weight="heavy")
plt.text(x_point, y_point, "x = %0.2f\ny = %0.2f"%(x_point, y_point), rotation=50, color='gray')

plt.show()

# %%
# I want 6 plots.

# STEP1) Draw 6 plots in tabular form with 2 rows and 3 columns 

plt.subplot(2, 3, 1) # 2 rows, 3 cols, 1st subplot
# plot code here

plt.subplot(2, 3, 2) 
# plot code here

plt.subplot(2, 3, 3) 
# plot code here

plt.subplot(2, 3, 4) 
# plot code here

plt.subplot(2, 3, 5) 
# plot code here

plt.subplot(2, 3, 6) 
# plot code here

plt.show()

# %%
# STEP2) Now lets fill in with some visuals

plt.subplot(2, 3, 1) # 2 rows, 3 cols, 1st subplot
x = np.linspace(-4, +4, 30)
y = 5*(x**2) -3*x + 1
plt.plot(x, y)


plt.subplot(2, 3, 2) 
x = np.linspace(-4, +4, 30)
y = 5*(x**3) -5*x +1
plt.plot(x, y)

plt.subplot(2, 3, 3) 
x = np.linspace(-4, +4, 30)
y = (x**3) -x + 5
plt.plot(x, y)

plt.subplot(2, 3, 4) 
x = np.linspace(-4, +4, 30)
y = (x**3) -x + 5
plt.plot(x, y)

plt.subplot(2, 3, 5) 
x = np.linspace(-4, +4, 30)
y = 5*(x**3) -5*x +1
plt.plot(x, y)

plt.subplot(2, 3, 6) 
x = np.linspace(-4, +4, 30)
y = -5*(x**2) -5*x +1
plt.plot(x, y)

plt.show()

# %%
# (SKIP) create a pair scatter matrix

# Sample data
data = np.array([
    [25, 50000, 700],
    [30, 60000, 720],
    [45, 80000, 680],
    [35, 75000, 690],
    [23, 52000, 710]
])

labels = ['Age', 'Income', 'Credit Score']
num_vars = data.shape[1]

fig, axes = plt.subplots(nrows=num_vars, ncols=num_vars, figsize=(8, 8))
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for i in range(num_vars):
    for j in range(num_vars):
        ax = axes[i, j]
        if i == j:
            ax.hist(data[:, i], bins=10, color='lightgray', edgecolor='black')
        else:
            ax.scatter(data[:, j], data[:, i], alpha=0.7)
        if i == num_vars - 1:
            ax.set_xlabel(labels[j], fontsize=9, rotation=45)
        else:
            ax.set_xticks([])
        if j == 0:
            ax.set_ylabel(labels[i], fontsize=9)
        else:
            ax.set_yticks([])

plt.suptitle("Manual Scatter Matrix", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# (SKIP)
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()
