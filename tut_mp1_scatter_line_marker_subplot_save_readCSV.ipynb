# %% [markdown]
# # Concepts covered
# - scatter, plot, line, marker, subplot
# - label x-axis, y-axis
# - adding title. legend
# - save figure into a file
# - read a CSV file

# %%
# import libraries
import matplotlib.pyplot as plt # create alias plt
import numpy as np

# Draw 3 points in the diagram,
# points (1,2), (4,9) and (3,2)
xpoints = np.array([1, 4, 3])
ypoints = np.array([2, 9, 2])

plt.scatter(xpoints, ypoints) # marker as o, *, +
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# simple scatter plot
x = np.array([5, 7, 8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# More realistic study hours vs. scores (8 points each)
x1_alice = np.array([3, 4, 5, 6, 7, 8, 9])  # hours Alice studied
y1_alice = np.array([55, 60, 70, 75, 78, 85, 88])  # Alice's scores
plt.scatter(x1_alice, y1_alice, color='red', label='Alice')

x2_bob = np.array([1, 2, 3, 4, 6, 7, 8])  # hours Bob studied
y2_bob = np.array([40, 50, 58, 63, 76, 82, 86])  # Bob's scores
plt.scatter(x2_bob, y2_bob, color='green', label='Bob')

plt.xlabel("Hours Studied")
plt.ylabel("Exam Score")
plt.title("Study Hours vs. Exam Scores")
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100]) # color each point

plt.scatter(x, y, c=colors, cmap='gist_earth') #TODO other cmap are Oranges viridis gist_earth

plt.colorbar()

plt.show()

# %%
# Create random arrays with 100 values for x-points, y-points, colors and sizes:
import matplotlib.pyplot as plt 
import numpy as np
 
# Generate 10 random points
x = np.array([20, 30, 40, 60, 80]) # age salary
y = np.array([20000, 45000, 60000, 30000, 50000]) # salary
colors = np.array([100, 50, 20, 100, 50]) # 3 department
sizes =  np.array([500, 60, 200, 60, 200]) # 3 title

# x = np.random.randint(20, 101, size=10)  # Age range: 20 to 100
# y = np.random.randint(20000, 70001, size=10)  # Income range: 20,000 to 70,000
# colors = np.random.randint(100, size=(10)) # department
# sizes = 10 * np.random.randint(100, size=(10)) # weight # TODO add position for shape

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral') #TODO change alpha from 0, 0.2, 0.5, 0.8, 1.

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# line through points (1,2),(4,9), (6,2)
xpoints = np.array([1, 4, 6])
ypoints = np.array([2, 9, 2])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Draw a line in a diagram from position (1, 3) to (2, 8) then to (6, 1) and finally to position (8, 10):
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Markers
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 3, 4])
ypoints = np.array([2, 6, 3, 9])

plt.plot(xpoints, ypoints, marker = 'D') # TODO try markers * . + o D etc
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

markers = [

'.', # point
',', # pixel
'o', # circle
'v', # triangle down
'^', # triangle up
'<', # triangle_left
'>', # triangle_right
'1', # tri_down
'2', # tri_up
'3', # tri_left
'4', # tri_right
'8', # octagon
's', # square
'p', # pentagon
'*', # star
'h', # hexagon1
'H', # hexagon2
'+', # plus
'x', # x
'D', # diamond
'd', # thin_diamond
'|', # vline

]

plt.figure(figsize=(13, 10))
samples = range(len(markers))


for i in samples:
    plt.plot([i-1, i, i+1], [i, i, i], label=markers[i], marker=markers[i], markersize=10)


# Annotation

plt.title('Matplotlib Marker styles', fontsize=20)
plt.ylim([-1, len(markers)+1])
plt.legend(loc='lower right')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 3, 4])
ypoints = np.array([3, 8, 1, 10])

# You can also use the shortcut string notation parameter to specify the marker.
# This parameter is also called fmt, and is written with this syntax: marker|line|color
plt.plot(xpoints,ypoints, 'o--b') # TODO other examples o--r o:g o:r o-r o-.r 'o--g'
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\path.py:129, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     101 """
#     102 Create a new path with the given vertices and codes.
#     103
#    (...)
#     127     and codes as read-only arrays.
#     128 """
# --> 129 vertices = _to_unmasked_float_array(vertices)
#     130 _api.check_shape((None, 2), vertices=vertices)
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\cbook.py:1355, in _to_unmasked_float_array(x)
#    1354 else:
# -> 1355     return np.asarray(x, float)
#
# ValueError: could not convert string to float: 'o--b'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 9
#       5 ypoints = np.array([3, 8, 1, 10])
#       7 # You can also use the shortcut string notation parameter to specify the marker.
#       8 # This parameter is also called fmt, and is written with this syntax: marker|line|color
# ----> 9 plt.plot(xpoints,ypoints, marker='o--b') # TODO other examples o--r o:g o:r o-r o-.r 'o--g'
#      10 plt.show()
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\pyplot.py:3827, in plot(scalex, scaley, data, *args, **kwargs)
#    3819 @_copy_docstring_and_deprecators(Axes.plot)
#    3820 def plot(
#    3821     *args: float | ArrayLike | str,
#    (...)
#    3825     **kwargs,
#    3826 ) -> list[Line2D]:
# -> 3827     return gca().plot(
#    3828         *args,
#    3829         scalex=scalex,
#    3830         scaley=scaley,
#    3831         **({"data": data} if data is not None else {}),
#    3832         **kwargs,
#    3833     )
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
#    1535 Plot y versus x as lines and/or markers.
#    1536
#    (...)
#    1774 (``'green'``) or hex strings (``'#008000'``).
#    1775 """
#    1776 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1777 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1778 for line in lines:
#    1779     self.add_line(line)
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_base.py:297, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     295     this += args[0],
#     296     args = args[1:]
# --> 297 yield from self._plot_args(
#     298     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     299     return_kwargs=return_kwargs
#     300 )
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_base.py:546, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     544     return list(result)
#     545 else:
# --> 546     return [l[0] for l in result]
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_base.py:546, in <listcomp>(.0)
#     544     return list(result)
#     545 else:
# --> 546     return [l[0] for l in result]
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_base.py:539, in <genexpr>(.0)
#     534 else:
#     535     raise ValueError(
#     536         f"label must be scalar or have the same length as the input "
#     537         f"data, but found {len(label)} for {n_datasets} datasets.")
# --> 539 result = (make_artist(axes, x[:, j % ncx], y[:, j % ncy], kw,
#     540                       {**kwargs, 'label': label})
#     541           for j, label in enumerate(labels))
#     543 if return_kwargs:
#     544     return list(result)
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\axes\_base.py:338, in _process_plot_var_args._make_line(self, axes, x, y, kw, kwargs)
#     336 kw = {**kw, **kwargs}  # Don't modify the original kw.
#     337 self._setdefaults(self._getdefaults(kw), kw)
# --> 338 seg = mlines.Line2D(x, y, **kw)
#     339 return seg, kw
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\lines.py:380, in Line2D.__init__(self, xdata, ydata, linewidth, linestyle, color, gapcolor, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     378     marker = 'none'  # Default.
#     379 if not isinstance(marker, MarkerStyle):
# --> 380     self._marker = MarkerStyle(marker, fillstyle)
#     381 else:
#     382     self._marker = marker
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\markers.py:248, in MarkerStyle.__init__(self, marker, fillstyle, transform, capstyle, joinstyle)
#     246 self._user_joinstyle = JoinStyle(joinstyle) if joinstyle is not None else None
#     247 self._set_fillstyle(fillstyle)
# --> 248 self._set_marker(marker)
#
# File c:\Users\UCT\Desktop\ashwani_stuff\DA_code\.venv\Lib\site-packages\matplotlib\markers.py:329, in MarkerStyle._set_marker(self, marker)
#     327         self._marker_function = self._set_vertices
#     328     except ValueError as err:
# --> 329         raise ValueError(
#     330             f'Unrecognized marker style {marker!r}') from err
#     332 if not isinstance(marker, MarkerStyle):
#     333     self._marker = marker
#
# ValueError: Unrecognized marker style 'o--b'

# %%
# marker size is 20
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 3, 4])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints, marker = 'o', ms = 20)# marker size
plt.show()

# %%
# Plot with a 20.5pt wide line:
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 2, 3, 4])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints,ypoints, linewidth = '10.5')
plt.show()

# %%
# Draw two lines by specifying a plt.plot() function for each line:
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([1, 2, 3, 4])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([1, 2, 3, 4])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1,y1)
plt.plot(x2,y2)

plt.show()

# %%
# Draw two lines by specifiyng the x- and y-point values for both lines:
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])

x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
# Labels
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Body Data", fontdict = font1)
plt.xlabel("Height", fontdict = font2)
plt.ylabel("weight", fontdict = font2)

plt.show()

# %% [markdown]
# ## Plot a curve and save the figure

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-4, 4, 30) # generate 30 points between -4 to +4
y = 5*(x**2) - 3*x + 1 # y = 5(x^2) -3x + 1
# y = -1.5*(x**3) + 10 # y = -1.5(x^3) + 10

plt.plot(x, y, marker="D")

plt.savefig("quad.png") # replaced plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-4, 4, 30) # generate 30 points between -4 to +4
y = 5*(x**2) - 3*x + 1 # y = 5(x^2) -3x + 1

plt.scatter(x, y, marker=".") # "g-"

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-1.5, 1.5, 30) # generate 30 points between -1.5 to +1.5
y = x**2

px = 0.8 # an x-point
py = px**2 # corresponding y point

#following plots a curve and a point
plt.plot(x, y, "g-", # plots a curve
         px, py, "ro" # plots a point
)

plt.text(0, 1.5, "Square function\n$y = x^2$", fontsize=20, color='red', horizontalalignment="center")
plt.text(px - 0.08, py, "Beautiful point", ha="right", weight="heavy")
plt.text(px, py, "x = %0.2f\ny = %0.2f"%(px, py), rotation=50, color='gray')

plt.show()

# %%
# annotate each points
# Sample data
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a scatter plot
fig, ax = plt.subplots()
ax.scatter(x, y, color='blue')

# Annotate points with text
ax.text(x[0], y[0], "Point 1", ha="center", va="center", color="black")
ax.text(x[1], y[1], "Point 2", ha="center", va="center", color="black")
ax.text(x[2], y[2], "Point 3", ha="center", va="center", color="black")

# or use for loop
# for i in range(len(x)):
#     ax.text(x[i], y[i], f"Point {i+1}", ha="center", va="center", color="black")

# Set labels and title
ax.set_title('Scatter Plot with Annotations')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')

# Show the plot
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.linspace(-1.5, 1.5, 30) # generate 30 points between -1.5 to +1.5

plt.plot(x, x**2, "b-", px, py, "ro")
plt.plot(x, -x**2, "g-", px, py, "ro")

plt.show()

# %%
# create a pair scatter matrix

# Sample data
data = np.array([
    [25, 50000, 700],
    [30, 60000, 720],
    [45, 80000, 680],
    [35, 75000, 690],
    [23, 52000, 710]
])

labels = ['Age', 'Income', 'Credit Score']
num_vars = data.shape[1]

fig, axes = plt.subplots(nrows=num_vars, ncols=num_vars, figsize=(8, 8))
fig.subplots_adjust(hspace=0.5, wspace=0.5)

for i in range(num_vars):
    for j in range(num_vars):
        ax = axes[i, j]
        if i == j:
            ax.hist(data[:, i], bins=10, color='lightgray', edgecolor='black')
        else:
            ax.scatter(data[:, j], data[:, i], alpha=0.7)
        if i == num_vars - 1:
            ax.set_xlabel(labels[j], fontsize=9, rotation=45)
        else:
            ax.set_xticks([])
        if j == 0:
            ax.set_ylabel(labels[i], fontsize=9)
        else:
            ax.set_yticks([])

plt.suptitle("Manual Scatter Matrix", fontsize=16)
plt.tight_layout()
plt.show()

# %%
# Draw 6 plots:
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

linestyles = ['-.', '--', 'None', '-', ':']

plt.figure(figsize=(8, 5))
samples = range(len(linestyles))


for i in samples:
    plt.plot([i-1, i, i+1], [i, i, i],
             label='"%s"' %linestyles[i],
             linestyle=linestyles[i],
             lw=4
             )

# Annotation

plt.title('Matplotlib line styles', fontsize=20)
plt.ylim([-1, len(linestyles)+1])
plt.legend(loc='lower right')


plt.show()

# %% [markdown]
# # reading from CSV file

# %%
# read from CSV file
import matplotlib.pyplot as plt # create alias plt
import pandas as pd

df = pd.read_csv("some_data.csv")

#Use below to read raw file directly from github. This is the URL obtained when we click raw button.
# df = pd.read_csv("https://raw.githubusercontent.com/ash322ash422/tut_matplotlib/bdbc0716c93775dd1995c841a290eebb67fecb61/some_data.csv")

print(f"df:\n{df}")
print("#######################")

xpoints = df['Sales']
ypoints = df['Expenses']

plt.scatter(xpoints, ypoints) # marker as o, *, +
plt.show()
# Out:
# df:
#           Date  Sales  Expenses  Profits
# 0    1/31/2023   3221      1373     1848
# 1    2/28/2023   2432      1300     1132
# 2    3/31/2023   1568       942      626
# 3    4/30/2023   1865      1834       31
# 4    5/31/2023   2113      1963      150
# 5    6/30/2023   2321      1869      452
# 6    7/31/2023   2814       831     1983
# 7    8/31/2023   1928      1141      787
# 8    9/30/2023   3879       622     3257
# 9   10/31/2023   4553       919     3634
# 10  11/30/2023   2497      1708      789
# 11  12/31/2023   1835      1075      760
# #######################
