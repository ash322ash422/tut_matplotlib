# %% [markdown]
# ## Violin Plot
# Violin Plot is used to visualize the distribution of numerical data of different variables. It is similar to Box Plot but with a rotated plot on each side, giving more information about the density estimate on the y-axis. The density is mirrored and flipped over, and the resulting shape is filled in, creating an image resembling a violin. Boxplot shows the outliers in the data lot clearly.
#
# Violin plots are used when you want to observe the distribution of numeric data, and are especially useful when you want to make a comparison of distributions between multiple groups. The peaks, valleys, and tails of each group’s density curve can be compared to see where groups are similar or different. Additional elements, like box plot quartiles, are often added to a violin plot to provide additional ways of comparing groups
# Violin Plots hold more information than box plots, they are less popular, because their meaning can be harder to grasp for many readers not familiar with the violin plot representation.
#
# The width of each curve corresponds with the approximate frequency of data points in each region.
#
# <img src="violin-plot.png" width="400" height="200">
#
# A violin plot consists of four components.
#
# 1. A white Centered Dot at the middle of the graph – The white dot point at the middle is the median of the distribution.
# 2. A thin gray bar inside the plot – The bar in the plot represents the Quartile range of the distribution.
# 3. A long thin line coming outside from the bar – The thin line represents the rest of the distribution which is calculated by the formulae Q1-1.5 IQR for the lower range and Q3+1.5 IQR for the upper range. The point lying beyond this line are considered as outliers.
# 4. A line boundary separating the plot- A KDE plot is used for defining the boundary of the violin plot it represents the distribution of data points.

# %% [markdown]
# ## bivariate analysis
# In bivariate analysis, violin plots are utilized to examine the relationship between a continuous variable and a categorical variable. The categorical variable is represented on the x-axis, while the y-axis represents the values of the continuous variable.

# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# a simple violin plot
# Generate random data
np.random.seed(2)

# Simulate realistic student test scores (mean ~70, std dev ~10)
data1 = np.random.normal(loc=70, scale=10, size=100)
data1 = np.clip(data1, 0, 100)  # Ensure scores are between 0 and 100

print(f"Student Scores:\n{data1}")
print("**************")

# Create a violin plot
plt.figure(figsize=(6, 4))
plt.violinplot(data1,
               showmedians=True
)

# Add labels for context
# plt.title("Distribution of Student Test Scores")
# plt.ylabel("Score out of 100")
# plt.xticks([1], ["Test 1"])
# plt.grid(True)
# plt.tight_layout()

plt.show()
# Out:
# Student Scores:
# [65.83242153 69.43733173 48.63803904 86.40270808 52.06564415 61.58252634
#  75.02881417 57.54711913 59.42047781 60.90992385 75.51454045 92.92208013
#  70.41539393 58.82074555 75.39058321 64.038403   69.80869503 81.7500122
#  62.52129051 70.09025251 61.21892107 68.4356583  72.56570452 60.11220951
#  66.61178034 67.63815969 63.62344988 58.12387714 55.78782773 68.46504804
#  67.3094304  92.31366789 45.65232423 71.12726505 73.70444537 83.59633863
#  75.01857207 61.55786296 70.00009761 75.42352572 66.86491803 77.71011738
#  51.31909345 87.31184666 84.67678011 66.64322661 76.1134078  70.47970592
#  61.70864711 70.87710218 80.00365887 66.18907482 66.24330577 69.25529237
#  74.3349633  82.7837923  63.65320695 75.08396243 72.16116006 51.41387614
#  65.80683518 68.67671102 69.6042976  73.26003433 49.59676951 70.46255523
#  63.22324423 55.60560973 75.2429643  77.35279576 63.46749732 78.42456282
#  66.18483518 70.66489009 59.01261053 85.84487056 43.40550544 69.08547377
#  76.95119605 49.66533454 68.10530735 69.22781335 78.24703005 82.48212921
#  65.96107731 56.15481333 83.67235424 82.17885633 65.37994652 73.50888494
#  73.81866234 75.66275441 72.04207979 84.06696242 52.62040496 80.40823953
#  73.8047197  67.82864731 81.73531498 46.56396809]
# **************

# %%
# VP with 3 different datas
# Generate random data
np.random.seed(2)

# Realistic average daily temperatures (in °C) for three different cities
city1_temps = np.random.normal(loc=15, scale=5, size=100)   # London
city2_temps = np.random.normal(loc=32, scale=3, size=100)   # Dubai
city3_temps = np.random.normal(loc=5, scale=4, size=100)    # Reykjavik

# Optional: clip to avoid unrealistic temps
city1_temps = np.clip(city1_temps, -5, 40)
city2_temps = np.clip(city2_temps, 20, 45)
city3_temps = np.clip(city3_temps, -10, 20)

print(f"City 1 (London):\n{city1_temps}")
print("**************")

# Combine data for plotting
all_data = [city1_temps, city2_temps, city3_temps]
categories = ['London', 'Dubai', 'Reykjavik']

# Violin plot
plt.figure(figsize=(8, 5))
plt.violinplot(all_data, showmedians=True)

# plt.xticks([1, 2, 3], categories)
# plt.ylabel("Temperature (°C)")
# plt.title("Simulated Daily Temperatures in Different Cities")
# plt.grid(True)
# plt.tight_layout()

plt.show()
# Out:
# City 1 (London):
# [12.91621076 14.71866586  4.31901952 23.20135404  6.03282207 10.79126317
#  17.51440709  8.77355957  9.71023891 10.45496193 17.75727022 26.46104006
#  15.20769696  9.41037277 17.6952916  12.0192015  14.90434752 20.8750061
#  11.26064525 15.04512625 10.60946053 14.21782915 16.28285226 10.05610476
#  13.30589017 13.81907985 11.81172494  9.06193857  7.89391386 14.23252402
#  13.6547152  26.15683394  2.82616212 15.56363252 16.85222268 21.79816931
#  17.50928603 10.77893148 15.00004881 17.71176286 13.43245902 18.85505869
#   5.65954673 23.65592333 22.33839005 13.32161331 18.0567039  15.23985296
#  10.85432355 15.43855109 20.00182943 13.09453741 13.12165288 14.62764619
#  17.16748165 21.39189615 11.82660347 17.54198121 16.08058003  5.70693807
#  12.90341759 14.33835551 14.8021488  16.63001717  4.79838476 15.23127762
#  11.61162211  7.80280487 17.62148215 18.67639788 11.73374866 19.21228141
#  13.09241759 15.33244505  9.50630527 22.92243528  1.70275272 14.54273689
#  18.47559803  4.83266727 14.05265368 14.61390667 19.12351503 21.2410646
#  12.98053865  8.07740667 21.83617712 21.08942817 12.68997326 16.75444247
#  16.90933117 17.83137721 16.02103989 22.03348121  6.31020248 20.20411977
#  16.90235985 13.91432366 20.86765749  3.28198405]
# **************

# %% [markdown]
# ## observation:
# - As you can see that the mean is 15, 33 and 4 for city1, city2 and city3 respectively

# %% [markdown]
# ## Application: Violin plot on Iris dataset

# %%
df = pd.read_csv('iris.csv') 
print(df.head())
# Out:
#    Unnamed: 0.1  Unnamed: 0  sepal length (cm)  sepal width (cm)  \
# 0             0           0                5.1               3.5
# 1             1           1                4.9               3.0
# 2             2           2                4.7               3.2
# 3             3           3                4.6               3.1
# 4             4           4                5.0               3.6
#
#    petal length (cm)  petal width (cm)  target species
# 0                1.4               0.2       0  setosa
# 1                1.4               0.2       0  setosa
# 2                1.3               0.2       0  setosa
# 3                1.5               0.2       0  setosa
# 4                1.4               0.2       0  setosa

# %%
print(df.describe())
# Out:
#        Unnamed: 0.1  Unnamed: 0  sepal length (cm)  sepal width (cm)  \
# count    150.000000  150.000000         150.000000        150.000000
# mean      74.500000   74.500000           5.843333          3.057333
# std       43.445368   43.445368           0.828066          0.435866
# min        0.000000    0.000000           4.300000          2.000000
# 25%       37.250000   37.250000           5.100000          2.800000
# 50%       74.500000   74.500000           5.800000          3.000000
# 75%      111.750000  111.750000           6.400000          3.300000
# max      149.000000  149.000000           7.900000          4.400000
#
#        petal length (cm)  petal width (cm)      target
# count         150.000000        150.000000  150.000000
# mean            3.758000          1.199333    1.000000
# std             1.765298          0.762238    0.819232
# min             1.000000          0.100000    0.000000
# 25%             1.600000          0.300000    0.000000
# 50%             4.350000          1.300000    1.000000
# 75%             5.100000          1.800000    2.000000
# max             6.900000          2.500000    2.000000

# %%
df['species'].unique() # lets see all categories for target
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
data = df["sepal length (cm)"]

plt.violinplot(data,
               # showmeans=True,
               showmedians=True
)
plt.title("Violin Plot of Sepal Length")
plt.ylabel("Sepal Length (cm)")
plt.xticks([1], ['sepal length (cm)'])  # Set x-axis label

plt.grid(True)
plt.show()

# %%
# Lets see if there is any relationship between 'sepal length' and 'target'

# Step 1: Filter data for each species using basic indexing (easy to follow)
col_name = "sepal length (cm)"
setosa_data     = df[df["species"] == "setosa"][col_name]
versicolor_data = df[df["species"] == "versicolor"][col_name]
virginica_data  = df[df["species"] == "virginica"][col_name]

# Step 2: Combine into a list (violinplot needs a list of arrays)
data_by_species = [setosa_data, versicolor_data, virginica_data]

# Step 3: Create violin plot
plt.violinplot(data_by_species, showmedians=True)

# Set x-axis labels
plt.xticks([1, 2, 3], species)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Lets see if there is any relationship between 'sepal width' and 'target'

# Step 1: Filter data for each species using basic indexing (easy to follow)
col_name = "sepal width (cm)"
setosa_data     = df[df["species"] == "setosa"][col_name]
versicolor_data = df[df["species"] == "versicolor"][col_name]
virginica_data  = df[df["species"] == "virginica"][col_name]

# Step 2: Combine into a list (violinplot needs a list of arrays)
data_by_species = [setosa_data, versicolor_data, virginica_data]

# Step 3: Create violin plot
plt.violinplot(data_by_species, showmedians=True)

# Set x-axis labels
plt.xticks([1, 2, 3], species)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Lets see if there is any relationship between 'petal length ' and 'target'

# Step 1: Filter data for each species using basic indexing (easy to follow)
col_name = "petal length (cm)"
setosa_data     = df[df["species"] == "setosa"][col_name]
versicolor_data = df[df["species"] == "versicolor"][col_name]
virginica_data  = df[df["species"] == "virginica"][col_name]

# Step 2: Combine into a list (violinplot needs a list of arrays)
data_by_species = [setosa_data, versicolor_data, virginica_data]

# Step 3: Create violin plot
plt.violinplot(data_by_species, showmedians=True)

# Set x-axis labels
plt.xticks([1, 2, 3], species)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Lets see if there is any relationship between 'petal width' and 'target'

# Step 1: Filter data for each species using basic indexing (easy to follow)
col_name = "petal width (cm)"
setosa_data     = df[df["species"] == "setosa"][col_name]
versicolor_data = df[df["species"] == "versicolor"][col_name]
virginica_data  = df[df["species"] == "virginica"][col_name]

# Step 2: Combine into a list (violinplot needs a list of arrays)
data_by_species = [setosa_data, versicolor_data, virginica_data]

# Step 3: Create violin plot
plt.violinplot(data_by_species, showmedians=True)

# Set x-axis labels
plt.xticks([1, 2, 3], species)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Clearly, violen plot shows that petal length and petal width are good indicators of types of iris flower.
